# %%
import pandas as pd
import numpy as np

# %%
ufc_ranking = pd.read_csv(r"C:\Users\Akoua Orsot\Desktop\ds_projects_data\rankings_history.csv")
ufc_ranking.head()
# Out:
#          date      weightclass            fighter  rank
# 0  2013-02-04  Pound-for-Pound     Anderson Silva     1
# 1  2013-02-04  Pound-for-Pound          Jon Jones     2
# 2  2013-02-04  Pound-for-Pound  Georges St-Pierre     3
# 3  2013-02-04  Pound-for-Pound          Jose Aldo     4
# 4  2013-02-04  Pound-for-Pound   Benson Henderson     5

# %%
champs = ufc_ranking[ufc_ranking["rank"]==0]
champs
# Out:
#              date            weightclass               fighter  rank
# 10     2013-02-04              Flyweight    Demetrious Johnson     0
# 21     2013-02-04           Bantamweight         Dominick Cruz     0
# 32     2013-02-04          Featherweight             Jose Aldo     0
# 43     2013-02-04            Lightweight      Benson Henderson     0
# 54     2013-02-04           Welterweight     Georges St-Pierre     0
# ...           ...                    ...                   ...   ...
# 60744  2021-12-06            Heavyweight       Francis Ngannou     0
# 60760  2021-12-06    Women's Strawweight        Rose Namajunas     0
# 60776  2021-12-06      Women's Flyweight  Valentina Shevchenko     0
# 60792  2021-12-06   Women's Bantamweight          Amanda Nunes     0
# 60808  2021-12-06  Women's Featherweight          Amanda Nunes     0
#
# [3677 rows x 4 columns]

# %%
champs = champs.drop(columns=['date', 'rank'], axis=1)
champs
# Out:
#                  weightclass               fighter
# 10                 Flyweight    Demetrious Johnson
# 21              Bantamweight         Dominick Cruz
# 32             Featherweight             Jose Aldo
# 43               Lightweight      Benson Henderson
# 54              Welterweight     Georges St-Pierre
# ...                      ...                   ...
# 60744            Heavyweight       Francis Ngannou
# 60760    Women's Strawweight        Rose Namajunas
# 60776      Women's Flyweight  Valentina Shevchenko
# 60792   Women's Bantamweight          Amanda Nunes
# 60808  Women's Featherweight          Amanda Nunes
#
# [3677 rows x 2 columns]

# %%
champs.dropna(inplace=True)
champs
# Out:
#                  weightclass               fighter
# 10                 Flyweight    Demetrious Johnson
# 21              Bantamweight         Dominick Cruz
# 32             Featherweight             Jose Aldo
# 43               Lightweight      Benson Henderson
# 54              Welterweight     Georges St-Pierre
# ...                      ...                   ...
# 60744            Heavyweight       Francis Ngannou
# 60760    Women's Strawweight        Rose Namajunas
# 60776      Women's Flyweight  Valentina Shevchenko
# 60792   Women's Bantamweight          Amanda Nunes
# 60808  Women's Featherweight          Amanda Nunes
#
# [3612 rows x 2 columns]

# %%
champs.drop_duplicates(inplace=True)
champs
# Out:
#                  weightclass                fighter
# 10                 Flyweight     Demetrious Johnson
# 21              Bantamweight          Dominick Cruz
# 32             Featherweight              Jose Aldo
# 43               Lightweight       Benson Henderson
# 54              Welterweight      Georges St-Pierre
# 65              Middleweight         Anderson Silva
# 76         Light Heavyweight              Jon Jones
# 87               Heavyweight         Cain Velasquez
# 490     Women's Bantamweight           Ronda Rousey
# 1438            Middleweight          Chris Weidman
# 1961             Lightweight         Anthony Pettis
# 3416            Bantamweight            Renan Barao
# 5214            Welterweight        Johny Hendricks
# 6757            Bantamweight           TJ Dillashaw
# 10306           Welterweight          Robbie Lawler
# 10529    Women's Strawweight          Carla Esparza
# 12024            Lightweight       Rafael Dos Anjos
# ...

# %%
champs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 10 to 59898
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   weightclass  57 non-null     object
#  1   fighter      57 non-null     object
# dtypes: object(2)
# memory usage: 3.4+ KB

# %%
champs_R = champs.rename(columns={"fighter":"R_fighter"})
champs_B = champs.rename(columns={"fighter":"B_fighter"})

# %%
ufc_master = pd.read_csv(r"C:\Users\Akoua Orsot\Desktop\ds_projects_data\ufc-master.csv")
ufc_master.head()
# Out:
#              R_fighter        B_fighter  R_odds  B_odds        R_ev  \
# 0        Thiago Santos    Johnny Walker  -150.0     130   66.666667
# 1        Alex Oliveira       Niko Price   170.0    -200  170.000000
# 2       Misha Cirkunov  Krzysztof Jotko   110.0    -130  110.000000
# 3  Alexander Hernandez     Mike Breeden  -675.0     475   14.814815
# 4          Joe Solecki     Jared Gordon  -135.0     115   74.074074
#
#          B_ev        date                location country Winner  ...  \
# 0  130.000000  2021-10-02  Las Vegas, Nevada, USA     USA    Red  ...
# 1   50.000000  2021-10-02  Las Vegas, Nevada, USA     USA   Blue  ...
# 2   76.923077  2021-10-02  Las Vegas, Nevada, USA     USA   Blue  ...
# 3  475.000000  2021-10-02  Las Vegas, Nevada, USA     USA    Red  ...
# 4  115.000000  2021-10-02  Las Vegas, Nevada, USA     USA   Blue  ...
#
#    finish_details finish_round finish_round_time  total_fight_time_secs  \
# ...

# %%
champs_fights_R = pd.merge(champs_R, ufc_master, on="R_fighter")
champs_fights_R
# Out:
#            weightclass           R_fighter           B_fighter  R_odds  \
# 0            Flyweight  Demetrious Johnson        Henry Cejudo  -470.0
# 1            Flyweight  Demetrious Johnson            Ray Borg -1000.0
# 2            Flyweight  Demetrious Johnson         Wilson Reis -1100.0
# 3            Flyweight  Demetrious Johnson         Tim Elliott  -900.0
# 4            Flyweight  Demetrious Johnson        Henry Cejudo  -340.0
# ..                 ...                 ...                 ...     ...
# 471  Light Heavyweight     Glover Teixeira  Ovince Saint Preux   120.0
# 472  Light Heavyweight     Glover Teixeira          Phil Davis  -210.0
# 473  Light Heavyweight     Glover Teixeira          Ryan Bader  -330.0
# 474  Light Heavyweight     Glover Teixeira       James Te Huna  -420.0
# 475  Light Heavyweight     Glover Teixeira     Fabio Maldonado  -475.0
#
#      B_odds        R_ev        B_ev        date  \
# 0       375   21.276596  375.000000    8/4/2018
# ...

# %%
champs_fights_B = pd.merge(champs_B, ufc_master, on="B_fighter")
champs_fights_B
# Out:
#            weightclass           B_fighter             R_fighter  R_odds  \
# 0            Flyweight  Demetrious Johnson      Joseph Benavidez  -245.0
# 1            Flyweight  Demetrious Johnson         Dominick Cruz  -550.0
# 2            Flyweight  Demetrious Johnson         Miguel Torres  -120.0
# 3            Flyweight  Demetrious Johnson     Norifumi Yamamoto  -115.0
# 4         Bantamweight       Dominick Cruz          Henry Cejudo  -225.0
# ..                 ...                 ...                   ...     ...
# 290  Light Heavyweight     Glover Teixeira  Alexander Gustafsson  -300.0
# 291  Light Heavyweight     Glover Teixeira       Anthony Johnson  -240.0
# 292  Light Heavyweight     Glover Teixeira             Jon Jones  -440.0
# 293  Light Heavyweight     Glover Teixeira       Rampage Jackson   215.0
# 294  Light Heavyweight     Glover Teixeira        Kyle Kingsbury   215.0
#
#      B_odds        R_ev        B_ev       date                    location  \
# ...

# %%
ufc_champs_final = pd.concat([champs_fights_R,champs_fights_B])
ufc_champs_final.to_csv('C:/Users/Akoua Orsot/Desktop/ds_projects_data/ufc_champs_final.csv')
